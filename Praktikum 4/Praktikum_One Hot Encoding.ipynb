# %%
import pandas as pd

data = pd.DataFrame({
  'warna': ['merah', 'hijau', 'biru', 'hijau'],
})

encoded = pd.get_dummies(data, dtype=int)
display(encoded)
# Out:
#    warna_biru  warna_hijau  warna_merah
# 0           0            0            1
# 1           0            1            0
# 2           1            0            0
# 3           0            1            0
